# %%
import pandas as pd
import numpy as np

# %%
import pymongo

# %%
df = pd.read_json("final_copy.json")

# %%
df
# Out:
#                         doi     coreId                                  oai  \
# 0                      None  210894674         oai:pure.mpg.de:item_2180255
# 1                      None   41507811               oai:edoc.mpg.de:204484
# 2                      None  111352030  oai:archive.serpentproject.com:2655
# 3                      None  111352032  oai:archive.serpentproject.com:2656
# 4                      None  111352033  oai:archive.serpentproject.com:2657
# ...                     ...        ...                                  ...
# 59995                  None   45725229               oai:edoc.mpg.de:315949
# 59996                  None   45725230               oai:edoc.mpg.de:315950
# 59997                  None   45725231               oai:edoc.mpg.de:315951
# 59998                  None   45725232               oai:edoc.mpg.de:315952
# 59999  10.1029/1998gl900131   45725233               oai:edoc.mpg.de:315953
#
# ...

# %%
df.columns
# Out:
# Index(['doi', 'coreId', 'oai', 'magId', 'identifiers', 'title', 'authors',
#        'enrichments', 'contributors', 'datePublished', 'abstract',
#        'downloadUrl', 'fullTextIdentifier', 'pdfHashValue', 'publisher',
#        'journals', 'language', 'relations', 'year', 'topics', 'subjects',
#        'fullText', 'urls', 'issn'],
#       dtype='object')

# %%
bool_series = pd.notnull(df["topics"])
df[bool_series]
# Out:
#                         doi     coreId                                  oai  \
# 0                      None  210894674         oai:pure.mpg.de:item_2180255
# 1                      None   41507811               oai:edoc.mpg.de:204484
# 2                      None  111352030  oai:archive.serpentproject.com:2655
# 3                      None  111352032  oai:archive.serpentproject.com:2656
# 4                      None  111352033  oai:archive.serpentproject.com:2657
# ...                     ...        ...                                  ...
# 59995                  None   45725229               oai:edoc.mpg.de:315949
# 59996                  None   45725230               oai:edoc.mpg.de:315950
# 59997                  None   45725231               oai:edoc.mpg.de:315951
# 59998                  None   45725232               oai:edoc.mpg.de:315952
# 59999  10.1029/1998gl900131   45725233               oai:edoc.mpg.de:315953
#
# ...

# %%
df[bool_series]
# Out:
#                         doi     coreId                                  oai  \
# 0                      None  210894674         oai:pure.mpg.de:item_2180255
# 1                      None   41507811               oai:edoc.mpg.de:204484
# 2                      None  111352030  oai:archive.serpentproject.com:2655
# 3                      None  111352032  oai:archive.serpentproject.com:2656
# 4                      None  111352033  oai:archive.serpentproject.com:2657
# ...                     ...        ...                                  ...
# 59995                  None   45725229               oai:edoc.mpg.de:315949
# 59996                  None   45725230               oai:edoc.mpg.de:315950
# 59997                  None   45725231               oai:edoc.mpg.de:315951
# 59998                  None   45725232               oai:edoc.mpg.de:315952
# 59999  10.1029/1998gl900131   45725233               oai:edoc.mpg.de:315953
#
# ...

# %%
replica = df.copy()

# %%
replica['topics'] = replica.topics.apply(lambda x:",".join(x))

# %%
replica
# Out:
#                         doi     coreId                                  oai  \
# 0                      None  210894674         oai:pure.mpg.de:item_2180255
# 1                      None   41507811               oai:edoc.mpg.de:204484
# 2                      None  111352030  oai:archive.serpentproject.com:2655
# 3                      None  111352032  oai:archive.serpentproject.com:2656
# 4                      None  111352033  oai:archive.serpentproject.com:2657
# ...                     ...        ...                                  ...
# 59995                  None   45725229               oai:edoc.mpg.de:315949
# 59996                  None   45725230               oai:edoc.mpg.de:315950
# 59997                  None   45725231               oai:edoc.mpg.de:315951
# 59998                  None   45725232               oai:edoc.mpg.de:315952
# 59999  10.1029/1998gl900131   45725233               oai:edoc.mpg.de:315953
#
# ...

# %%
bool_series = pd.notnull(replica["topics"])
replica[bool_series]
# Out:
#                         doi     coreId                                  oai  \
# 0                      None  210894674         oai:pure.mpg.de:item_2180255
# 1                      None   41507811               oai:edoc.mpg.de:204484
# 2                      None  111352030  oai:archive.serpentproject.com:2655
# 3                      None  111352032  oai:archive.serpentproject.com:2656
# 4                      None  111352033  oai:archive.serpentproject.com:2657
# ...                     ...        ...                                  ...
# 59995                  None   45725229               oai:edoc.mpg.de:315949
# 59996                  None   45725230               oai:edoc.mpg.de:315950
# 59997                  None   45725231               oai:edoc.mpg.de:315951
# 59998                  None   45725232               oai:edoc.mpg.de:315952
# 59999  10.1029/1998gl900131   45725233               oai:edoc.mpg.de:315953
#
# ...

# %%
replica.topics.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# %%
replica
# Out:
#                         doi     coreId                                  oai  \
# 0                      None  210894674         oai:pure.mpg.de:item_2180255
# 1                      None   41507811               oai:edoc.mpg.de:204484
# 2                      None  111352030  oai:archive.serpentproject.com:2655
# 3                      None  111352032  oai:archive.serpentproject.com:2656
# 4                      None  111352033  oai:archive.serpentproject.com:2657
# ...                     ...        ...                                  ...
# 59995                  None   45725229               oai:edoc.mpg.de:315949
# 59996                  None   45725230               oai:edoc.mpg.de:315950
# 59997                  None   45725231               oai:edoc.mpg.de:315951
# 59998                  None   45725232               oai:edoc.mpg.de:315952
# 59999  10.1029/1998gl900131   45725233               oai:edoc.mpg.de:315953
#
# ...

# %%
bool_series = pd.notnull(replica["topics"])
replica[bool_series]
# Out:
#                                     doi     coreId  \
# 2                                  None  111352030
# 3                                  None  111352032
# 4                                  None  111352033
# 5                                  None  111352034
# 6                                  None  111352035
# ...                                 ...        ...
# 59950          10.1177/1352458510382933   45795216
# 59956           10.1073/pnas.0805616105   45759463
# 59962                10.1101/gad.471408   45759469
# 59964  10.1111/j.1528-1167.2008.01550.x   45759471
# 59971           10.1038/sj.ejhg.5201967   45759478
#
#                                        oai         magId identifiers  \
# 2      oai:archive.serpentproject.com:2655           NaN          []
# 3      oai:archive.serpentproject.com:2656           NaN          []
# 4      oai:archive.serpentproject.com:2657           NaN          []
# 5      oai:archive.serpentproject.com:2658           NaN          []
# ...

# %%
replica['journals'] = replica.journals.astype('str')

# %%
replica.journals.unique()
# Out:
# array(['[]',
#        "[{'identifiers': ['0278-0062', 'issn:0278-0062'], 'title': 'IEEE Transactions on Medical Imaging'}]",
#        "[{'identifiers': ['2380-7504', 'issn:2380-7504'], 'title': None}]",
#        "[{'identifiers': ['0143-974x', 'issn:0143-974X'], 'title': 'Journal of Constructional Steel Research'}]"],
#       dtype=object)

# %%
replica['subjects'] = replica.subjects.astype('str')
replica.subjects.unique()
# Out:
# array(["['info:eu-repo/semantics/lecture']", "['Conference-Paper']",
#        "['Image']", "['Thesis', 'doctoral', 'PhD']",
#        "['Article', 'published version paper']",
#        "['Book chapter', 'published version paper']",
#        "['Thesis', 'doctoral', 'DBA']",
#        "['Article', 'Accepted Manuscript']",
#        "['Article', 'Published version']",
#        "['Book chapter', 'No full-text in the repository']",
#        "['Article', 'No full-text in the repository']",
#        "['Report', 'Published version']",
#        "['Editorial', 'No full-text available in the repository']",
#        "['Article', 'No full-text available in the repository']",
#        "['Book chapter', 'No full-text available in the repository']",
#        "['Conference Paper', 'No full-text available in the repository']",
#        "['Article']", "['Book', 'No full-text in the repository']",
#        "['Article', 'Post-print']", "['Post-print']",
# ...

# %%
len(replica.subjects.unique())
# Out:
# 287

# %%
df2 = replica.groupby(['subjects'])['subjects'].count().sort_values(ascending=False)

# %%
df2[:5]
# Out:
# subjects
# ['Article']             31320
# ['InBook']               4624
# ['Conference-Paper']     4319
# ['Talk at Event']        2169
# ['PhD-Thesis']           1558
# Name: subjects, dtype: int64

# %%
len(list(replica.publisher.unique()))
# Out:
# 3627

# %%
df2 = replica.groupby(['publisher'])['publisher'].count().sort_values(ascending=False)[:5]

# %%
df2
# Out:
# publisher
# 'Elsevier BV'                                1266
# Springer                                      818
# 'Wiley'                                       623
# 'Springer Science and Business Media LLC'     560
# Oceaneering                                   420
# Name: publisher, dtype: int64

# %%
df2 = replica.groupby(['year'])['year'].count().sort_values(ascending=False)

# %%
df2
# Out:
# year
# 2009.0      4589
# 2007.0      4487
# 2005.0      4222
# 2004.0      4174
# 2003.0      4129
#             ...
# 1918.0         1
# 1913.0         1
# 1912.0         1
# 1906.0         1
# 201502.0       1
# Name: year, Length: 85, dtype: int64

# %%
replica.relations[2]
# Out:
# ['http://archive.serpentproject.com/2655/01/DSCN6626.JPG',
#  'http://archive.serpentproject.com/2655/02/DSCN6627.JPG',
#  'http://archive.serpentproject.com/2655/03/DSCN6620.JPG',
#  'http://archive.serpentproject.com/2655/04/DSCN6624.JPG',
#  'http://archive.serpentproject.com/2655/05/DSCN6622.JPG']

# %%
replica.enrichments[59950]
# Out:
# {'references': [],
#  'citationCount': 2,
#  'documentType': {'type': None, 'confidence': None}}

# %%
bool_series = pd.notnull(replica["doi"])
replica[bool_series]
# Out:
#                                  doi     coreId  \
# 16      10.1080/14703297.2013.778048   11304206
# 29      10.7861/clinmedicine.18-1-47  153515631
# 33                10.1111/reel.12147  153515635
# 34     10.1016/j.ibusrev.2017.10.007  153515636
# 35     10.1016/j.jbusres.2017.10.042  153515637
# ...                              ...        ...
# 59988                 10.1086/307529   45725222
# 59991   10.1007/978-94-015-9167-6_47   45725225
# 59992              10.1029/98je02248   45725226
# 59993           10.1029/1998gl900252   45725227
# 59999           10.1029/1998gl900131   45725233
#
#                                            oai         magId identifiers  \
# 16      oai:bradscholars.brad.ac.uk:10454/5520           NaN          []
# 29     oai:bradscholars.brad.ac.uk:10454/14183           NaN          []
# 33     oai:bradscholars.brad.ac.uk:10454/14222  2.343084e+09          []
# 34     oai:bradscholars.brad.ac.uk:10454/14223           NaN          []
# ...
